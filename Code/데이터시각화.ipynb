# %%
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# fonts-nanum is already the newest version (20170925-1).
# 0 upgraded, 0 newly installed, 0 to remove and 37 not upgraded.
# /usr/share/fonts: caching, new cache contents: 0 fonts, 1 dirs
# /usr/share/fonts/truetype: caching, new cache contents: 0 fonts, 3 dirs
# /usr/share/fonts/truetype/humor-sans: caching, new cache contents: 1 fonts, 0 dirs
# /usr/share/fonts/truetype/liberation: caching, new cache contents: 16 fonts, 0 dirs
# /usr/share/fonts/truetype/nanum: caching, new cache contents: 10 fonts, 0 dirs
# /usr/local/share/fonts: caching, new cache contents: 0 fonts, 0 dirs
# /root/.local/share/fonts: skipping, no such directory
# /root/.fonts: skipping, no such directory
# /var/cache/fontconfig: cleaning cache directory
# /root/.cache/fontconfig: not cleaning non-existent cache directory
# /root/.fontconfig: not cleaning non-existent cache directory
# fc-cache: succeeded

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

data1=pd.read_excel('/content/drive/Shareddrives/쥰나쎄/데이터셋/1. 관광숙박업.xlsx')
data2=pd.read_excel('/content/drive/Shareddrives/쥰나쎄/데이터셋/2. 관광펜션업.xlsx')
data3=pd.read_excel('/content/drive/Shareddrives/쥰나쎄/데이터셋/3. 숙박업.xlsx')
data4=pd.read_excel('/content/drive/Shareddrives/쥰나쎄/데이터셋/4. 외국인관광도시민박업.xlsx')
data5=pd.read_excel('/content/drive/Shareddrives/쥰나쎄/데이터셋/5. 자동차야영장업.xlsx')
data6=pd.read_excel('/content/drive/Shareddrives/쥰나쎄/데이터셋/6. 한옥체험업.xlsx')
data7=pd.read_excel('/content/drive/Shareddrives/쥰나쎄/데이터셋/7. 일반야영장업.xlsx')

# %% [markdown]
# ## 특정column 추출하기

# %%
Df1 = data1[['개방서비스명', '개방자치단체코드', '인허가일자', '영업상태구분코드', '폐업일자', '휴업시작일자', '사업장명', '좌표정보(X)', '좌표정보(Y)','소재지면적','영업상태명']]
Df2 = data2[['개방서비스명', '개방자치단체코드', '인허가일자', '영업상태구분코드', '폐업일자', '휴업시작일자', '사업장명', '좌표정보(X)', '좌표정보(Y)','소재지면적','영업상태명']]
Df3 = data3[['개방서비스명', '개방자치단체코드', '인허가일자', '영업상태구분코드', '폐업일자', '휴업시작일자', '사업장명', '좌표정보(X)', '좌표정보(Y)','소재지면적','영업상태명']]
Df4 = data4[['개방서비스명', '개방자치단체코드', '인허가일자', '영업상태구분코드', '폐업일자', '휴업시작일자', '사업장명', '좌표정보(X)', '좌표정보(Y)','소재지면적','영업상태명']]
Df5 = data5[['개방서비스명', '개방자치단체코드', '인허가일자', '영업상태구분코드', '폐업일자', '휴업시작일자', '사업장명', '좌표정보(X)', '좌표정보(Y)','소재지면적','영업상태명']]
Df6 = data6[['개방서비스명', '개방자치단체코드', '인허가일자', '영업상태구분코드', '폐업일자', '휴업시작일자', '사업장명', '좌표정보(X)', '좌표정보(Y)','소재지면적','영업상태명']]
Df7 = data7[['개방서비스명', '개방자치단체코드', '인허가일자', '영업상태구분코드', '폐업일자', '휴업시작일자', '사업장명', '좌표정보(X)', '좌표정보(Y)','소재지면적','영업상태명']]

# %%
Df = Df1.append(Df2)
DDf = Df.append(Df3)
DDDf = DDf.append(Df4)
DDDDf = DDDf.append(Df5)
DDDDDf = DDDDf.append(Df6)
df = DDDDDf.append(Df7)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 67010 entries, 0 to 3024
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   개방서비스명    67010 non-null  object
#  1   개방자치단체코드  67010 non-null  int64
#  2   인허가일자     67010 non-null  int64
#  3   영업상태구분코드  67010 non-null  int64
#  4   폐업일자      27421 non-null  float64
#  5   휴업시작일자    345 non-null    float64
#  6   사업장명      67010 non-null  object
#  7   좌표정보(X)   62694 non-null  float64
#  8   좌표정보(Y)   62694 non-null  float64
#  9   소재지면적     53611 non-null  object
#  10  영업상태명     67010 non-null  object
# dtypes: float64(4), int64(3), object(4)
# memory usage: 6.1+ MB

# %%
df.reset_index(inplace=True)

# %%
df.drop('index',axis=1,inplace=True)

# %%
df
# Out:
#        개방서비스명  개방자치단체코드     인허가일자  ...        좌표정보(Y)  소재지면적  영업상태명
# 0       관광숙박업   3000000  20201023  ...  452339.843126    NaN  영업/정상
# 1       관광숙박업   3000000  20180618  ...  452574.992954    NaN     폐업
# 2       관광숙박업   3000000  20191029  ...  452223.097221    NaN  영업/정상
# 3       관광숙박업   3000000  20191018  ...  452611.575937    NaN  영업/정상
# 4       관광숙박업   3000000  20191002  ...  452473.403750    NaN  영업/정상
# ...       ...       ...       ...  ...            ...    ...    ...
# 67005  일반야영장업   6520000  20200603  ...  -11127.015467    NaN  영업/정상
# 67006  일반야영장업   6520000  20150522  ...  -28313.642298    NaN  영업/정상
# 67007  일반야영장업   6520000  20160509  ...  -26932.445735    NaN  영업/정상
# 67008  일반야영장업   6520000  20150727  ...  -20459.431963    NaN  영업/정상
# 67009  일반야영장업   6520000  20160610  ...  -31335.071295    NaN     폐업
#
# [67010 rows x 11 columns]

# %%
df1 = df.astype({'개방자치단체코드':'str'})
df2 = df1.astype({'영업상태구분코드':'str'})
df3 = df2.astype({'인허가일자':'str'})
df4 = df3.astype({'폐업일자':'str'})
df5 = df4.astype({'휴업시작일자':'str'})
df = df5.astype({'소재지면적':'str'})

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 67010 entries, 0 to 67009
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   개방서비스명    67010 non-null  object
#  1   개방자치단체코드  67010 non-null  object
#  2   인허가일자     67010 non-null  object
#  3   영업상태구분코드  67010 non-null  object
#  4   폐업일자      67010 non-null  object
#  5   휴업시작일자    67010 non-null  object
#  6   사업장명      67010 non-null  object
#  7   좌표정보(X)   62694 non-null  float64
#  8   좌표정보(Y)   62694 non-null  float64
#  9   소재지면적     67010 non-null  object
#  10  영업상태명     67010 non-null  object
# dtypes: float64(2), object(9)
# memory usage: 5.6+ MB

# %%
df['폐업일자'] = df['폐업일자'].str.replace('\.0','')
df['휴업시작일자'] = df['휴업시작일자'].str.replace('\.0','')

# %%
#잘못된 형식 파악
print(df[pd.to_datetime(df['인허가일자'],format='%Y%m%d', errors='coerce').isnull()]['인허가일자'].value_counts())
print(df[pd.to_datetime(df['폐업일자'],format='%Y%m%d', errors='coerce').isnull()]['폐업일자'].value_counts())
print(df[pd.to_datetime(df['휴업시작일자'],format='%Y%m%d', errors='coerce').isnull()]['휴업시작일자'].value_counts())
# Out:
# 19940431    1
# 19970230    1
# 19750229    1
# 19840431    1
# Name: 인허가일자, dtype: int64
# nan         39589
# 200204          1
# 199909          1
# 20020231        1
# 200003          1
# 20020230        1
# 2014            1
# 200009          1
# Name: 폐업일자, dtype: int64
# nan    66665
# Name: 휴업시작일자, dtype: int64

# %%
df['인허가일자'] = pd.to_datetime(df['인허가일자'],format='%Y%m%d', errors='coerce')
df['폐업일자'] = pd.to_datetime(df['폐업일자'],format='%Y%m%d', errors='coerce')
df['휴업시작일자'] = pd.to_datetime(df['휴업시작일자'],format='%Y%m%d', errors='coerce')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 67010 entries, 0 to 67009
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   개방서비스명    67010 non-null  object
#  1   개방자치단체코드  67010 non-null  object
#  2   인허가일자     67006 non-null  datetime64[ns]
#  3   영업상태구분코드  67010 non-null  object
#  4   폐업일자      27414 non-null  datetime64[ns]
#  5   휴업시작일자    345 non-null    datetime64[ns]
#  6   사업장명      67010 non-null  object
#  7   좌표정보(X)   62694 non-null  float64
#  8   좌표정보(Y)   62694 non-null  float64
#  9   소재지면적     67010 non-null  object
#  10  영업상태명     67010 non-null  object
# dtypes: datetime64[ns](3), float64(2), object(6)
# memory usage: 5.6+ MB

# %%
df.head()
# Out:
#   개방서비스명 개방자치단체코드      인허가일자  ...        좌표정보(Y) 소재지면적  영업상태명
# 0  관광숙박업  3000000 2020-10-23  ...  452339.843126   nan  영업/정상
# 1  관광숙박업  3000000 2018-06-18  ...  452574.992954   nan     폐업
# 2  관광숙박업  3000000 2019-10-29  ...  452223.097221   nan  영업/정상
# 3  관광숙박업  3000000 2019-10-18  ...  452611.575937   nan  영업/정상
# 4  관광숙박업  3000000 2019-10-02  ...  452473.403750   nan  영업/정상
#
# [5 rows x 11 columns]

# %% [markdown]
# #개방자치단체코드, 전국 코로나

# %%
covid = pd.read_excel('/content/drive/Shareddrives/쥰나쎄/데이터셋/전국 코로나19.xlsx')
code = pd.read_excel('/content/drive/Shareddrives/쥰나쎄/데이터셋/개방자치단체코드목록(참고).xlsx')

# %%
code
# Out:
#       번호      시도명  시도(자치단체)코드  시군구명  시군구(자치단체)코드
# 0      1    서울특별시   6110000.0   종로구    3000000.0
# 1      2      NaN         NaN    중구    3010000.0
# 2      3      NaN         NaN   용산구    3020000.0
# 3      4      NaN         NaN   성동구    3030000.0
# 4      5      NaN         NaN   광진구    3040000.0
# ..   ...      ...         ...   ...          ...
# 225  226      NaN         NaN   거창군    5470000.0
# 226  227      NaN         NaN   합천군    5480000.0
# 227  228      NaN         NaN   창원시    5670000.0
# 228  229  제주특별자치도   6500000.0   제주시    6510000.0
# 229  230      NaN         NaN  서귀포시    6520000.0
#
# [230 rows x 5 columns]

# %%
covid
# Out:
#      전국 추가 확진  전국 사망      전국 기준일
# 0        6603   6480  2022/01/20
# 1        5805   6452  2022/01/19
# 2        4072   6378  2022/01/18
# 3        3859   6333  2022/01/17
# 4        4194   6310  2022/01/16
# ..        ...    ...         ...
# 712         0      0  2020/02/09
# 713         0      0  2020/02/08
# 714         0      0  2020/02/07
# 715         0      0  2020/02/06
# 716         0      0  2020/02/05
#
# [717 rows x 3 columns]

# %%
code[code['시군구(자치단체)코드'].isna()]
# Out:
#     번호      시도명  시도(자치단체)코드 시군구명  시군구(자치단체)코드
# 74  75  세종특별자치시   5690000.0  NaN          NaN

# %%
code['시군구(자치단체)코드'].fillna({74:5690000.0}, inplace=True)
code.loc[[74]]
# Out:
#     번호      시도명  시도(자치단체)코드 시군구명  시군구(자치단체)코드
# 74  75  세종특별자치시   5690000.0  NaN    5690000.0

# %%
code['개방자치단체코드'] = code['시군구(자치단체)코드'].astype(int)
code
# Out:
#       번호      시도명  시도(자치단체)코드  시군구명  시군구(자치단체)코드  개방자치단체코드
# 0      1    서울특별시   6110000.0   종로구    3000000.0   3000000
# 1      2      NaN         NaN    중구    3010000.0   3010000
# 2      3      NaN         NaN   용산구    3020000.0   3020000
# 3      4      NaN         NaN   성동구    3030000.0   3030000
# 4      5      NaN         NaN   광진구    3040000.0   3040000
# ..   ...      ...         ...   ...          ...       ...
# 225  226      NaN         NaN   거창군    5470000.0   5470000
# 226  227      NaN         NaN   합천군    5480000.0   5480000
# 227  228      NaN         NaN   창원시    5670000.0   5670000
# 228  229  제주특별자치도   6500000.0   제주시    6510000.0   6510000
# 229  230      NaN         NaN  서귀포시    6520000.0   6520000
#
# [230 rows x 6 columns]

# %%
code = code[['시도명','시군구명','개방자치단체코드']]
code
# Out:
#          시도명  시군구명  개방자치단체코드
# 0      서울특별시   종로구   3000000
# 1        NaN    중구   3010000
# 2        NaN   용산구   3020000
# 3        NaN   성동구   3030000
# 4        NaN   광진구   3040000
# ..       ...   ...       ...
# 225      NaN   거창군   5470000
# 226      NaN   합천군   5480000
# 227      NaN   창원시   5670000
# 228  제주특별자치도   제주시   6510000
# 229      NaN  서귀포시   6520000
#
# [230 rows x 3 columns]

# %%
code['시도명'].fillna(method = 'pad', inplace=True)
code
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/series.py:4536: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   downcast=downcast,
#          시도명  시군구명  개방자치단체코드
# 0      서울특별시   종로구   3000000
# 1      서울특별시    중구   3010000
# 2      서울특별시   용산구   3020000
# 3      서울특별시   성동구   3030000
# 4      서울특별시   광진구   3040000
# ..       ...   ...       ...
# 225     경상남도   거창군   5470000
# 226     경상남도   합천군   5480000
# 227     경상남도   창원시   5670000
# 228  제주특별자치도   제주시   6510000
# 229  제주특별자치도  서귀포시   6520000
#
# [230 rows x 3 columns]

# %%
df
# Out:
#        개방서비스명 개방자치단체코드      인허가일자  ...        좌표정보(Y) 소재지면적  영업상태명
# 0       관광숙박업  3000000 2020-10-23  ...  452339.843126   nan  영업/정상
# 1       관광숙박업  3000000 2018-06-18  ...  452574.992954   nan     폐업
# 2       관광숙박업  3000000 2019-10-29  ...  452223.097221   nan  영업/정상
# 3       관광숙박업  3000000 2019-10-18  ...  452611.575937   nan  영업/정상
# 4       관광숙박업  3000000 2019-10-02  ...  452473.403750   nan  영업/정상
# ...       ...      ...        ...  ...            ...   ...    ...
# 67005  일반야영장업  6520000 2020-06-03  ...  -11127.015467   nan  영업/정상
# 67006  일반야영장업  6520000 2015-05-22  ...  -28313.642298   nan  영업/정상
# 67007  일반야영장업  6520000 2016-05-09  ...  -26932.445735   nan  영업/정상
# 67008  일반야영장업  6520000 2015-07-27  ...  -20459.431963   nan  영업/정상
# 67009  일반야영장업  6520000 2016-06-10  ...  -31335.071295   nan     폐업
#
# [67010 rows x 11 columns]

# %%
code
# Out:
#          시도명  시군구명  개방자치단체코드
# 0      서울특별시   종로구   3000000
# 1      서울특별시    중구   3010000
# 2      서울특별시   용산구   3020000
# 3      서울특별시   성동구   3030000
# 4      서울특별시   광진구   3040000
# ..       ...   ...       ...
# 225     경상남도   거창군   5470000
# 226     경상남도   합천군   5480000
# 227     경상남도   창원시   5670000
# 228  제주특별자치도   제주시   6510000
# 229  제주특별자치도  서귀포시   6520000
#
# [230 rows x 3 columns]

# %%
code.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 230 entries, 0 to 229
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   시도명       230 non-null    object
#  1   시군구명      229 non-null    object
#  2   개방자치단체코드  230 non-null    int64
# dtypes: int64(1), object(2)
# memory usage: 5.5+ KB

# %%
df = df.astype({'개방자치단체코드':'int'})

# %%
code.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 230 entries, 0 to 229
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   시도명       230 non-null    object
#  1   시군구명      229 non-null    object
#  2   개방자치단체코드  230 non-null    int64
# dtypes: int64(1), object(2)
# memory usage: 5.5+ KB

# %%
df_code = pd.merge(left = code,
                       right = df,
                       how = 'right',
                       left_on = '개방자치단체코드',
                       right_on = '개방자치단체코드')
df_code
# Out:
#          시도명 시군구명  개방자치단체코드  ...        좌표정보(Y)     소재지면적  영업상태명
# 0      서울특별시  종로구   3000000  ...  452339.843126       nan  영업/정상
# 1      서울특별시  종로구   3000000  ...  452574.992954       nan     폐업
# 2      서울특별시  종로구   3000000  ...  452223.097221       nan  영업/정상
# 3      서울특별시  종로구   3000000  ...  452611.575937       nan  영업/정상
# 4      서울특별시  종로구   3000000  ...  452473.403750       nan  영업/정상
# ...      ...  ...       ...  ...            ...       ...    ...
# 67005   충청남도  계룡시   5580000  ...  308096.375000  1,567.97     폐업
# 67006   충청남도  계룡시   5580000  ...            NaN       .00     폐업
# 67007   충청남도  계룡시   5580000  ...  308227.488983       nan     폐업
# 67008   충청남도  계룡시   5580000  ...  308049.683343  1,999.00     폐업
# 67009   충청남도  계룡시   5580000  ...  308210.624473  1,464.40  영업/정상
#
# [67010 rows x 13 columns]

# %%
df_code[df_code['휴업시작일자'].notnull()]
# Out:
#          시도명 시군구명  개방자치단체코드  ...        좌표정보(Y) 소재지면적 영업상태명
# 41     서울특별시  종로구   3000000  ...  452035.412647   nan    휴업
# 42     서울특별시  종로구   3000000  ...  452419.429557   nan    휴업
# 651    서울특별시  종로구   3000000  ...  454148.715955   nan    휴업
# 1049   서울특별시   중구   3010000  ...  450878.102981   nan    휴업
# 1840   서울특별시   중구   3010000  ...  450160.928264   nan    휴업
# ...      ...  ...       ...  ...            ...   ...   ...
# 66715   충청남도  금산군   4550000  ...  284086.402073   nan    휴업
# 66761   전라북도  진안군   4730000  ...  272646.698548   nan    휴업
# 66795   전라북도  장수군   4750000  ...  244986.554676   nan    휴업
# 66827   전라북도  임실군   4760000  ...  240967.405814   nan    휴업
# 66981   경상남도  함안군   5400000  ...  199904.852271   nan    휴업
#
# [345 rows x 13 columns]

# %%
df_code.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 67010 entries, 0 to 67009
# Data columns (total 13 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   시도명       67010 non-null  object
#  1   시군구명      66881 non-null  object
#  2   개방자치단체코드  67010 non-null  int64
#  3   개방서비스명    67010 non-null  object
#  4   인허가일자     67006 non-null  datetime64[ns]
#  5   영업상태구분코드  67010 non-null  object
#  6   폐업일자      27414 non-null  datetime64[ns]
#  7   휴업시작일자    345 non-null    datetime64[ns]
#  8   사업장명      67010 non-null  object
#  9   좌표정보(X)   62694 non-null  float64
#  10  좌표정보(Y)   62694 non-null  float64
#  11  소재지면적     67010 non-null  object
#  12  영업상태명     67010 non-null  object
# dtypes: datetime64[ns](3), float64(2), int64(1), object(7)
# memory usage: 7.2+ MB

# %% [markdown]
# #업종별 분석

# %%
df_code_service = df_code[['개방서비스명','영업상태명']]
df_code_service
# Out:
#       개방서비스명  영업상태명
# 0      관광숙박업  영업/정상
# 1      관광숙박업     폐업
# 2      관광숙박업  영업/정상
# 3      관광숙박업  영업/정상
# 4      관광숙박업  영업/정상
# ...      ...    ...
# 67005    숙박업     폐업
# 67006    숙박업     폐업
# 67007    숙박업     폐업
# 67008    숙박업     폐업
# 67009    숙박업  영업/정상
#
# [67010 rows x 2 columns]

# %%
df_gg = df_code_service[df_code_service['개방서비스명'] == '관광숙박업']

# %%
df_gg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3055 entries, 0 to 64582
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   개방서비스명  3055 non-null   object
#  1   영업상태명   3055 non-null   object
# dtypes: object(2)
# memory usage: 71.6+ KB

# %%
df_gg[df_gg['영업상태명']=='영업/정상'].count()
# Out:
# 개방서비스명    2389
# 영업상태명     2389
# dtype: int64

# %%
df_gg[df_gg['영업상태명']=='폐업'].count()
# Out:
# 개방서비스명    503
# 영업상태명     503
# dtype: int64

# %%
df_gg[df_gg['영업상태명'] == '휴업'].count()
# Out:
# 개방서비스명    115
# 영업상태명     115
# dtype: int64

# %% [markdown]
# ## 관광 숙박업

# %%
import matplotlib.pyplot as plt
plt.rc('font', family='NanumBarunGothic')
plt.figure(figsize=(10,10))
size = [2389,503,115]
label = ['영업','폐업','휴업']
color = ['green','red','yellow']
plt.axis('equal')
plt.pie(size, labels=label, autopct='%.1f%%', colors=color,explode=(0.1,0,0),shadow=True,startangle=60,textprops={'fontsize':16})
plt.legend()
plt.title('관광 숙박업', fontsize=20)
plt.show()

# %%
df_ps = df_code_service[df_code_service['개방서비스명'] == '관광펜션업']
df_ps[df_ps['영업상태명']=='영업/정상'].count()
# Out:
# 개방서비스명    592
# 영업상태명     592
# dtype: int64

# %%
df_ps[df_ps['영업상태명']=='폐업'].count()
# Out:
# 개방서비스명    231
# 영업상태명     231
# dtype: int64

# %%
df_ps[df_ps['영업상태명'] == '휴업'].count()
# Out:
# 개방서비스명    5
# 영업상태명     5
# dtype: int64

# %% [markdown]
# ## 관광 펜션업

# %%
import matplotlib.pyplot as plt
plt.rc('font', family='NanumBarunGothic')
plt.figure(figsize=(10,10))
size = [592,231,5]
label = ['영업','폐업','휴업']
color = ['green','red','yellow']
plt.axis('equal')
plt.pie(size, labels=label, autopct='%.1f%%', colors=color,explode=(0.1,0,0),shadow=True,startangle=90,textprops={'fontsize':16})
plt.legend()
plt.title('관광 펜션업', fontsize=20)
plt.show()

# %%
df_sb = df_code_service[df_code_service['개방서비스명'] == '숙박업']
df_sb[df_sb['영업상태명']=='영업/정상'].count()
# Out:
# 개방서비스명    29999
# 영업상태명     29999
# dtype: int64

# %%
df_sb[df_sb['영업상태명']=='폐업'].count()
# Out:
# 개방서비스명    23993
# 영업상태명     23993
# dtype: int64

# %%
df_sb[df_sb['영업상태명'] == '휴업'].count()
# Out:
# 개방서비스명    0
# 영업상태명     0
# dtype: int64

# %% [markdown]
# ## 숙박업

# %%
import matplotlib.pyplot as plt
plt.rc('font', family='NanumBarunGothic')
plt.figure(figsize=(10,10))
size = [29999,23993,0]
label = ['영업','폐업','휴업']
color = ['green','red','yellow']
plt.axis('equal')
plt.pie(size, labels=label, autopct='%.1f%%', colors=color,explode=(0.1,0,0),shadow=True,startangle=90,textprops={'fontsize':16})
plt.legend()
plt.title('숙박업', fontsize=20)
plt.show()

# %%
df_dm = df_code_service[df_code_service['개방서비스명'] == '외국인관광도시민박업']
df_dm[df_dm['영업상태명']=='영업/정상'].count()
# Out:
# 개방서비스명    1794
# 영업상태명     1794
# dtype: int64

# %%
df_dm[df_dm['영업상태명']=='폐업'].count()
# Out:
# 개방서비스명    1630
# 영업상태명     1630
# dtype: int64

# %%
df_dm[df_dm['영업상태명'] == '휴업'].count()
# Out:
# 개방서비스명    69
# 영업상태명     69
# dtype: int64

# %% [markdown]
# ## 외국인 관광도시 민박업

# %%
import matplotlib.pyplot as plt
plt.rc('font', family='NanumBarunGothic')
plt.figure(figsize=(10,10))
size = [1794,1630,69]
label = ['영업','폐업','휴업']
color = ['green','red','yellow']
plt.axis('equal')
plt.pie(size, labels=label, autopct='%.1f%%', colors=color,explode=(0.05,0,0),shadow=True,startangle=90,textprops={'fontsize':16})
plt.legend()
plt.title('외국인 관광도시 민박업', fontsize=20)
plt.show()

# %%
df_jy = df_code_service[df_code_service['개방서비스명'] == '자동차야영장업']
df_jy[df_jy['영업상태명']=='영업/정상'].count()
# Out:
# 개방서비스명    509
# 영업상태명     509
# dtype: int64

# %%
df_jy[df_jy['영업상태명']=='폐업'].count()
# Out:
# 개방서비스명    72
# 영업상태명     72
# dtype: int64

# %%
df_jy[df_jy['영업상태명'] == '휴업'].count()
# Out:
# 개방서비스명    22
# 영업상태명     22
# dtype: int64

# %% [markdown]
# ## 자동차 야영장업

# %%
import matplotlib.pyplot as plt
plt.rc('font', family='NanumBarunGothic')
plt.figure(figsize=(10,10))
size = [509,72,22]
label = ['영업','폐업','휴업']
color = ['green','red','yellow']
plt.axis('equal')
plt.pie(size, labels=label, autopct='%.1f%%', colors=color,explode=(0.1,0,0),shadow=True,startangle=90,textprops={'fontsize':16})
plt.legend()
plt.title('자동차 야영장업', fontsize=20)
plt.show()

# %%
df_ho = df_code_service[df_code_service['개방서비스명'] == '한옥체험업']
df_ho[df_ho['영업상태명']=='영업/정상'].count()
# Out:
# 개방서비스명    1547
# 영업상태명     1547
# dtype: int64

# %%
df_ho[df_ho['영업상태명']=='폐업'].count()
# Out:
# 개방서비스명    365
# 영업상태명     365
# dtype: int64

# %%
df_ho[df_ho['영업상태명'] == '휴업'].count()
# Out:
# 개방서비스명    15
# 영업상태명     15
# dtype: int64

# %% [markdown]
# ## 한옥 체험업

# %%
import matplotlib.pyplot as plt
plt.rc('font', family='NanumBarunGothic')
plt.figure(figsize=(10,10))
size = [1547,365,15]
label = ['영업','폐업','휴업']
color = ['green','red','yellow']
plt.axis('equal')
plt.pie(size, labels=label, autopct='%.1f%%', colors=color,explode=(0.1,0,0),shadow=True,startangle=60,textprops={'fontsize':16})
plt.legend()
plt.title('한옥 체험업', fontsize=20)

plt.show()

# %%
df_iy = df_code_service[df_code_service['개방서비스명'] == '일반야영장업']
df_iy[df_iy['영업상태명']=='영업/정상'].count()
# Out:
# 개방서비스명    2237
# 영업상태명     2237
# dtype: int64

# %%
df_iy[df_iy['영업상태명']=='폐업'].count()
# Out:
# 개방서비스명    538
# 영업상태명     538
# dtype: int64

# %%
df_iy[df_iy['영업상태명'] == '휴업'].count()
# Out:
# 개방서비스명    134
# 영업상태명     134
# dtype: int64

# %% [markdown]
# ## 일반 야영장업

# %%
import matplotlib.pyplot as plt
plt.rc('font', family='NanumBarunGothic')
plt.figure(figsize=(10,10))
size = [2237,538,134]
label = ['영업','폐업','휴업']
color = ['green','red','yellow']
plt.axis('equal')
plt.pie(size, labels=label, autopct='%.1f%%', colors=color,explode=(0.1,0,0),shadow=True,startangle=60,textprops={'fontsize':16})
plt.legend()
plt.title('일반 야영장업', fontsize=20)
plt.show()

# %% [markdown]
# ##업종별 전체 막대그래프

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.rc('font', family='NanumBarunGothic')
plt.figure(figsize=(20,10))

a = np.array([[79.4,71.5,55.6,51.4,84.4,80.3,76.9],[3.8,0.6,0.0,2.0,3.6,0.8,4.6],[16.7,27.9,44.4,46.7,11.9,18.9,18.5]])
X = np.arange(7)
names = ['관광숙박업','관광펜션업','숙박업','외국인관광도시민박업','자동차야영장업','한옥체험업','일반야영장업']
labels = ['10%','20%','30%','40%','50%','60%','70%','80%']
p1 = plt.bar(X - 0.25, a[0], color = 'green', width = 0.25)
p2 = plt.bar(X + 0.00, a[1], color = 'yellow', width = 0.25)
p3 = plt.bar(X + 0.25, a[2], color = 'r', width = 0.25)

plt.xticks(X,names,fontsize=15)
plt.yticks(fontsize=15)
plt.ylabel('비율(%)',fontsize=20)
plt.xlabel('업종',fontsize=20)
plt.title('업종별 현황', fontsize=30)

plt.legend((p1[0],p2[0],p3[0]),('영업','휴업','폐업'), fontsize=15)


plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.rc('font', family = 'NanumBarunGothic')
plt.figure(figsize=(20,10))

names = ['관광숙박업','관광펜션업','숙박업','외국인관광도시민박업','자동차야영장업','한옥체험업','일반야영장업']
p1 = [79.4,71.5,55.6,51.4,84.4,80.3,76.9]
p2 = [3.8,0.6,0.0,2.0,3.6,0.8,4.6]
p3 = [16.7,27.9,44.4,46.7,11.9,18.9,18.5]


plt.plot(names,p1,'o-',label='영업',c='g')
plt.plot(names,p2,'o-',label='휴업',c='yellow')
plt.plot(names,p3,'o-',label='폐업',c='r')

plt.title('<업종별 현황>')
plt.xlabel('업종', fontsize=15)
plt.ylabel('비율(%)', fontsize=15)

plt.legend()
plt.grid()

# %%
plt.rc('font', family='NanumBarunGothic')
plt.figure(figsize=(20,10))
plt.style.use('ggplot')

a = np.array([[79.4,71.5,55.6,51.4,84.4,80.3,76.9],[3.8,0.6,0.0,2.0,3.6,0.8,4.6],[16.7,27.9,44.4,46.7,11.9,18.9,18.5]])
X = np.arange(7)
names = ['관광숙박업','관광펜션업','숙박업','외국인관광도시민박업','자동차야영장업','한옥체험업','일반야영장업']
labels = ['10%','20%','30%','40%','50%','60%','70%','80%']
p1 = plt.bar(X - 0.125, a[0], color = 'green', width = 0.25)
p2 = plt.bar(X + 0.125, a[1], color = 'yellow', width = 0.25, bottom=a[2])
p3 = plt.bar(X + 0.125, a[2], color = 'r', width = 0.25)

plt.xticks(X,names,fontsize=15)
plt.yticks(fontsize=15)
plt.ylabel('비율(%)',fontsize=20)
plt.xlabel('업종',fontsize=20)
plt.title('업종별 현황', fontsize=30)

plt.legend((p1[0],p2[0],p3[0]),('영업','휴업','폐업'), fontsize=15)


plt.show()

# %% [markdown]
# #시계열 현황에 대한 현황

# %%
df_code
# Out:
#          시도명 시군구명  개방자치단체코드  ...        좌표정보(Y)     소재지면적  영업상태명
# 0      서울특별시  종로구   3000000  ...  452339.843126       nan  영업/정상
# 1      서울특별시  종로구   3000000  ...  452574.992954       nan     폐업
# 2      서울특별시  종로구   3000000  ...  452223.097221       nan  영업/정상
# 3      서울특별시  종로구   3000000  ...  452611.575937       nan  영업/정상
# 4      서울특별시  종로구   3000000  ...  452473.403750       nan  영업/정상
# ...      ...  ...       ...  ...            ...       ...    ...
# 67005   충청남도  계룡시   5580000  ...  308096.375000  1,567.97     폐업
# 67006   충청남도  계룡시   5580000  ...            NaN       .00     폐업
# 67007   충청남도  계룡시   5580000  ...  308227.488983       nan     폐업
# 67008   충청남도  계룡시   5580000  ...  308049.683343  1,999.00     폐업
# 67009   충청남도  계룡시   5580000  ...  308210.624473  1,464.40  영업/정상
#
# [67010 rows x 13 columns]

# %%
df_code_cu = df_code[['인허가일자','영업상태명']]
df_code_pau = df_code[['폐업일자','영업상태명']]
df_code_hu = df_code[['휴업시작일자','영업상태명']]

# %%
df_p = df_code_pau[df_code_pau['영업상태명']=='폐업']
df_p.reset_index(inplace=True)
df_p.drop('index',axis=1,inplace=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:4174: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
df_p
# Out:
#             폐업일자 영업상태명
# 0     2020-10-08    폐업
# 1     2020-12-10    폐업
# 2     2020-09-08    폐업
# 3     2021-12-29    폐업
# 4     2020-03-30    폐업
# ...          ...   ...
# 27327 2020-03-14    폐업
# 27328 2017-05-30    폐업
# 27329 2004-06-16    폐업
# 27330 2014-03-25    폐업
# 27331 2017-02-22    폐업
#
# [27332 rows x 2 columns]

# %%
df_p[df_p['폐업일자']=='2020-10-08'].count()
# Out:
# 폐업일자     7
# 영업상태명    7
# dtype: int64

# %%
df_p['폐업일자'][0].year
# Out:
# 2020

# %%
year = df_p['폐업일자'].map(lambda d: d.year)

# %%
years = pd.DataFrame(year)
years.dropna(inplace=True)
years = years.astype(int)
years
# Out:
#        폐업일자
# 0      2020
# 1      2020
# 2      2020
# 3      2021
# 4      2020
# ...     ...
# 27327  2020
# 27328  2017
# 27329  2004
# 27330  2014
# 27331  2017
#
# [27304 rows x 1 columns]

# %%
df_p['폐업일자'].dropna(inplace=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df_p['폐업일자'] = years['폐업일자']
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df_p.sort_values(by='폐업일자',
                ascending=True,
                inplace=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
df_p['폐업일자'].unique()
# Out:
# array([1900., 1967., 1968., 1972., 1974., 1975., 1980., 1983., 1984.,
#        1985., 1986., 1987., 1988., 1989., 1990., 1991., 1992., 1993.,
#        1994., 1995., 1996., 1997., 1998., 1999., 2000., 2001., 2002.,
#        2003., 2004., 2005., 2006., 2007., 2008., 2009., 2010., 2011.,
#        2012., 2013., 2014., 2015., 2016., 2017., 2018., 2019., 2020.,
#        2021.,   nan])

# %%
df_h = df_code_hu[df_code_hu['영업상태명']=='휴업']
year2=df_h['휴업시작일자'].map(lambda d: d.year)
year2.dropna(inplace=True)

# %%
years2 = year2.astype(int)
years2=pd.DataFrame(years2)
df_h['휴업시작일자']=years2['휴업시작일자']
df_h.sort_values(by='휴업시작일자',
                ascending=True,
                inplace=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df_h['휴업시작일자'].unique()
# Out:
# array([2001., 2005., 2006., 2010., 2012., 2013., 2014., 2015., 2016.,
#        2017., 2018., 2019., 2020., 2021., 2022.,   nan])

# %%
df_h.dropna(inplace=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df_h['휴업시작일자'].unique()
# Out:
# array([2001., 2005., 2006., 2010., 2012., 2013., 2014., 2015., 2016.,
#        2017., 2018., 2019., 2020., 2021., 2022.])

# %%
df_cu = df_code[['인허가일자','영업상태명']]
df_code_cu['인허가일자']
# Out:
# 0       2020-10-23
# 1       2018-06-18
# 2       2019-10-29
# 3       2019-10-18
# 4       2019-10-02
#            ...
# 67005   2003-02-27
# 67006   2003-02-27
# 67007   2003-06-09
# 67008   2003-05-28
# 67009   2003-02-27
# Name: 인허가일자, Length: 67010, dtype: datetime64[ns]

# %%
df_c = df_code_cu[df_code_hu['영업상태명']=='영업/정상']
year3=df_c['인허가일자'].map(lambda d: d.year)
year3.dropna(inplace=True)

# %%
years3 = year3.astype(int)
years3=pd.DataFrame(years3)
df_c['인허가일자']=years3['인허가일자']
df_c.sort_values(by='인허가일자',
                ascending=True,
                inplace=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df_c.dropna(inplace=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df_c['인허가일자'].unique()
# Out:
# array([1900., 1924., 1957., 1958., 1959., 1960., 1961., 1962., 1963.,
#        1964., 1965., 1966., 1967., 1968., 1969., 1970., 1971., 1972.,
#        1973., 1974., 1975., 1976., 1977., 1978., 1979., 1980., 1981.,
#        1982., 1983., 1984., 1985., 1986., 1987., 1988., 1989., 1990.,
#        1991., 1992., 1993., 1994., 1995., 1996., 1997., 1998., 1999.,
#        2000., 2001., 2002., 2003., 2004., 2005., 2006., 2007., 2008.,
#        2009., 2010., 2011., 2012., 2013., 2014., 2015., 2016., 2017.,
#        2018., 2019., 2020., 2021.])

# %%
df_p.reset_index(inplace=True)
df_p.drop('index',axis=1,inplace=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:4174: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
df_p.dropna(inplace=True)
df_p
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#          폐업일자 영업상태명
# 0      1900.0    폐업
# 1      1967.0    폐업
# 2      1967.0    폐업
# 3      1968.0    폐업
# 4      1972.0    폐업
# ...       ...   ...
# 27299  2021.0    폐업
# 27300  2021.0    폐업
# 27301  2021.0    폐업
# 27302  2021.0    폐업
# 27303  2021.0    폐업
#
# [27304 rows x 2 columns]

# %%
df_p['폐업일자'].unique()
# Out:
# array([1900., 1967., 1968., 1972., 1974., 1975., 1980., 1983., 1984.,
#        1985., 1986., 1987., 1988., 1989., 1990., 1991., 1992., 1993.,
#        1994., 1995., 1996., 1997., 1998., 1999., 2000., 2001., 2002.,
#        2003., 2004., 2005., 2006., 2007., 2008., 2009., 2010., 2011.,
#        2012., 2013., 2014., 2015., 2016., 2017., 2018., 2019., 2020.,
#        2021.])

# %%
df_c['인허가일자'].unique()
# Out:
# array([1900., 1924., 1957., 1958., 1959., 1960., 1961., 1962., 1963.,
#        1964., 1965., 1966., 1967., 1968., 1969., 1970., 1971., 1972.,
#        1973., 1974., 1975., 1976., 1977., 1978., 1979., 1980., 1981.,
#        1982., 1983., 1984., 1985., 1986., 1987., 1988., 1989., 1990.,
#        1991., 1992., 1993., 1994., 1995., 1996., 1997., 1998., 1999.,
#        2000., 2001., 2002., 2003., 2004., 2005., 2006., 2007., 2008.,
#        2009., 2010., 2011., 2012., 2013., 2014., 2015., 2016., 2017.,
#        2018., 2019., 2020., 2021.])

# %%
df_h['휴업시작일자'].unique()
# Out:
# array([2001., 2005., 2006., 2010., 2012., 2013., 2014., 2015., 2016.,
#        2017., 2018., 2019., 2020., 2021., 2022.])

# %%
x = [2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021]
y = [442,612,1036,2275,1285,1327,1326,1177,928,775,823,811,911,756,898,983,1183,1531,1835,1526,1608,1688]
result1 = pd.DataFrame({'연도':x,
                        '폐업합계':y})
result1
# Out:
#       연도  폐업합계
# 0   2000   442
# 1   2001   612
# 2   2002  1036
# 3   2003  2275
# 4   2004  1285
# 5   2005  1327
# 6   2006  1326
# 7   2007  1177
# 8   2008   928
# 9   2009   775
# 10  2010   823
# 11  2011   811
# 12  2012   911
# 13  2013   756
# 14  2014   898
# 15  2015   983
# 16  2016  1183
# 17  2017  1531
# 18  2018  1835
# 19  2019  1526
# 20  2020  1608
# 21  2021  1688

# %%
x = [2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021]
y = [1081,948,1186,3045,1228,521,487,467,452,365,683,602,914,1017,1299,2091,1949,1834,1778,1701,1510,2023]
result2 = pd.DataFrame({'연도':x,
                        '영업합계':y})
result2
# Out:
#       연도  영업합계
# 0   2000  1081
# 1   2001   948
# 2   2002  1186
# 3   2003  3045
# 4   2004  1228
# 5   2005   521
# 6   2006   487
# 7   2007   467
# 8   2008   452
# 9   2009   365
# 10  2010   683
# 11  2011   602
# 12  2012   914
# 13  2013  1017
# 14  2014  1299
# 15  2015  2091
# 16  2016  1949
# 17  2017  1834
# 18  2018  1778
# 19  2019  1701
# 20  2020  1510
# 21  2021  2023

# %%
x = [2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021]
y = [0,1,0,0,0,2,3,0,0,0,1,0,4,1,1,1,4,7,20,38,86,162]
result3 = pd.DataFrame({'연도':x,
                        '휴업합계':y})
result3
# Out:
#       연도  휴업합계
# 0   2000     0
# 1   2001     1
# 2   2002     0
# 3   2003     0
# 4   2004     0
# 5   2005     2
# 6   2006     3
# 7   2007     0
# 8   2008     0
# 9   2009     0
# 10  2010     1
# 11  2011     0
# 12  2012     4
# 13  2013     1
# 14  2014     1
# 15  2015     1
# 16  2016     4
# 17  2017     7
# 18  2018    20
# 19  2019    38
# 20  2020    86
# 21  2021   162

# %% [markdown]
# # 시계열 현황에 대한 현황 시각화

# %%
plt.figure(figsize=(20,10))
plt.subplot(121)
plt.plot(result1['연도'],result1['폐업합계'],color='r',label='폐업',marker='o')
plt.plot(result2['연도'],result2['영업합계'],color='g',label='영업',marker='*')
plt.xlabel('연도', fontsize=20)
plt.ylabel('합계(개)',fontsize=20)
plt.title('<연도별 현황>',fontsize=25)
plt.legend(fontsize=15)

plt.subplot(122)
plt.bar(result3['연도'],result3['휴업합계'],color='y',label='휴업')
plt.plot(result3['연도'],result3['휴업합계'],color='darkorange',marker='s')

plt.xlabel('연도', fontsize=20)
plt.ylabel('합계(개)',fontsize=20)
plt.title('<연도별 현황>',fontsize=25)
plt.legend(fontsize=15)
plt.show()

# %%
df_code
# Out:
#          시도명 시군구명  개방자치단체코드  ...        좌표정보(Y)     소재지면적  영업상태명
# 0      서울특별시  종로구   3000000  ...  452339.843126       nan  영업/정상
# 1      서울특별시  종로구   3000000  ...  452574.992954       nan     폐업
# 2      서울특별시  종로구   3000000  ...  452223.097221       nan  영업/정상
# 3      서울특별시  종로구   3000000  ...  452611.575937       nan  영업/정상
# 4      서울특별시  종로구   3000000  ...  452473.403750       nan  영업/정상
# ...      ...  ...       ...  ...            ...       ...    ...
# 67005   충청남도  계룡시   5580000  ...  308096.375000  1,567.97     폐업
# 67006   충청남도  계룡시   5580000  ...            NaN       .00     폐업
# 67007   충청남도  계룡시   5580000  ...  308227.488983       nan     폐업
# 67008   충청남도  계룡시   5580000  ...  308049.683343  1,999.00     폐업
# 67009   충청남도  계룡시   5580000  ...  308210.624473  1,464.40  영업/정상
#
# [67010 rows x 13 columns]
